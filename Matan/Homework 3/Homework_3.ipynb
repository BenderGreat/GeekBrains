# %% [markdown]
# ####  Урок 3. Вебинар “Множество. Последовательность”

# %% [markdown]
# ##### Домашнее задание N3
# Слушатель: Перфильев Дмитрий

# %% [markdown]
# #### Математическая логика
#
# #### 1) Проверить любым способ, является ли данная логическая формула тавтологией:
#
# ##### a. (𝐴 ∪ 𝐵) → (𝐵 ∪ ¬𝐴)

# %% [markdown]
# #### Решение:
#
# 𝐴 = 'И', 𝐵 = 'Л', ¬𝐴 = 'Л', тогда
#
# 'И' ∪ 'Л' → 'Л' ∪ 'Л' = 'И' → 'Л' =  'Л'
#
# 𝐴 = 'И' а B = 'И' ¬𝐴 = 'Л', тогда
#
# 'И' ∪ 'И' → 'И' ∪ 'Л' = 'И' → 'И' =  'И'
#
# #### Ответ:
# Данная логическая формула не является тавтологией т.к. не является истинной при любых входящих значениях простых элементов

# %% [markdown]
# ##### b. 𝐴 → (𝐴 ∪ (¬𝐵 ∩ 𝐴))

# %% [markdown]
# #### Решение:
#
# 𝐴 = 'И', ¬𝐵 = 'И',  тогда
# 'И' → ('И' ∪ ('И' ∩ 'И')) = 'И' → ('И' ∪ 'И') = 'И' → 'И' = 'И'
#
# 𝐴 = 'Л', ¬𝐵 = 'Л', тогда
# 'Л' → ('Л' ∪ ('Л' ∩ 'Л')) = 'Л' → ('Л' ∪ 'Л') = 'Л' → 'Л' = 'И'
#
# 𝐴 = 'Л', ¬𝐵 = 'И', тогда
# 'Л' → ('Л' ∪ ('И' ∩ 'Л')) = 'Л' → ('Л' ∪ 'Л') = 'Л' → 'Л' =  'И'
#
# 𝐴 = 'И', ¬𝐵 = 'Л', тогда
# 'И' → ('И' ∪ ('Л' ∩ 'И')) = 'И' → ('И' ∪ 'Л') = 'И' → 'И' = 'И'
#
# #### Ответ:
# Данная логическая формула является тавтологией т.к. является истинной при любых входящих значениях простых элементов

# %% [markdown]
# #### 2) Сформулируйте словесно высказывания:
# ##### a. ¬𝐴 ∪ 𝐵 → ¬𝐶
# ##### А: сегодня светит солнце; В: сегодня сыро; С: я поеду на дачу.

# %% [markdown]
# #### Ответ:
# Если не сегодня светит солнце или сегодня сыро, то не я поеду на дачу

# %% [markdown]
# ##### b. 𝐶 → 𝐴 ∪ ¬𝐵
#
# ##### А: сегодня светит солнце; В: сегодня сыро; С: я поеду на дачу.

# %% [markdown]
# #### Ответ:
# Если я поеду на дачу, то сегодня светит солнце или не сегодня сыро

# %% [markdown]
# #### 3) Пользуясь правилом построения противоположного высказывания, записать утверждения, противоположные следующим:
# ##### a. На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».

# %% [markdown]
# #### Ответ:
# Существует курс и факультет на котором все студенты, не сдают экзамены на «отлично».

# %% [markdown]
# ##### b. Каждый студент философского факультета имеет друга, который умеет решать все логические задачи.

# %% [markdown]
# #### Ответ:
# Есть студент филосовского факультета у которого все друзья, не могут решить хотя бы одну логическую задачу.

# %% [markdown]
# ##### c. В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой  пуговице одежды которого вмонтирован микрофон.

# %% [markdown]
# #### Ответ:
# Есть самолет на рейсе Вашингтон-Москва на которм нет ни одного сотрудника силовых органов, хотя бы в одной пуговице которго не вмонтирован микрофон.

# %% [markdown]
# #### Множества. Предел последовательности
#
# #### 4) Представьте в виде несократимой рациональной дроби:
# ##### a. 0. (216)

# %% [markdown]
# #### Решение:
# a = 0.(216)
#
# 1000*a = 216 + a
#
# 999*a = 216
#
# a = 216/999
#
# a = 24/111
#
# #### Ответ:
# a = 24/111

# %% [markdown]
# ##### b. 1.0(01)

# %% [markdown]
# #### Решение:
# a = 1.0(01)
#
# 10*a = 10 + 0.(01)
#
# 10*a = 10 + b
#
# b = 0.(01)
#
# b = 1/99
#
# 10*a = 10 + 1/99
#
# a = 991/990
#
# #### Ответ:
# a = 991/990

# %% [markdown]
# #### 5) Представьте 1 в виде суммы трех рациональных дробей с разными знаменателями и числителем равным 1.

# %% [markdown]
# 1/x + 1/y + 1/z = 1
#
# xy = z
# если x = 2
#
# то y = 3,
# z = 6
#
# #### Ответ: 1/2 + 1/3 + 1/6

# %% [markdown]
# #### 7. Найдите значение предела:
#
# Предел суммы будет меньше суммы членов убывающей геометрической прогрессии 1/2, 1/4, ... 1/2*(1/2)^n-1 т.к. каждый член данной меньше соответствующего члена геометрической прогрессии. Следовательно при n стремящейся к бесконечности сумма будет стремиться к 1.
#
# #### Ответ: lim = 1;
