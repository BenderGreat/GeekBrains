# %% [markdown]
# #### Урок 2. Видеоурок “Множество. Последовательность”

# %% [markdown]
# ##### Домашнее задание N2
# Слушатель: Перфильев Дмитрий

# %% [markdown]
# #### Как относятся друг к другу множество и последовательность? (в ответе использовать слова типа: часть, целое, общее, частное, родитель, дочерний субъект и т.д.)

# %% [markdown]
# Последовательность относится к множеству как дочений субьек этого множества, такой что для каждого натурального числа можно  указать элемент данного множества. Элементы последовательности будут принадлежать данному множеству.

# %% [markdown]
# #### Прочитать высказывания математической логики, построить их отрицания и установить истинность.

# %% [markdown]
# 1) Утверждение: ∀y ∈[0;1] ∶ sgn(y)=1
#
# Ответ:
# утверждение ложно
#
# Отрицание:    ∃y ∈ [0;1] ∶ sgn(y)≠1 -
# отрицание верно

# %% [markdown]
# 2) Утверждение: ∀n ∈ N> 2 ∶ ∃x,y,z ∈ N ∶ x^n= y^n+z^n
#
# Ответ:
# утверждение справедливо
#
# Отрицание:   ∃n ∈ N > 2 ∶ ∀x,y,z ∈ N ∶ x^n ≠ y^n+z^n -
# отрицание ложно

# %% [markdown]
# 3) Утверждение: ∀x∈R ∃X∈R∶ X>x
#
# Ответ:
# утверждение справедливо
#
# Отрицание:   ∃x∈R ∀X∈R∶ X<x -
# отрицание ложно

# %% [markdown]
# 4) Утверждение: ∀x∈C ∄y∈C ∶ x>y||x<y
#
# Ответ:
# утверждение справедливо
#
# Отрицание:   ∃x∈C ∀y∈C  ∶ x<y||x>y -
# отрицание ложно

# %% [markdown]
# 5) Утверждение: ∀y∈[0;π/2]  ∃ε>0 ∶ sin(y)<sin⁡(y+ε)
#
# Ответ:
# утверждение ложно
#
# Отрицание:   ∃y∈[0;π/2]  ∀ε≤0 ∶ sin(y)>sin⁡(y+ε)
# отрицание справедливо

# %% [markdown]
# 6) Утверждение: ∀y∈[0;π) ∃ε>0 ∶ cos(y)>cos⁡(y+ε)
#
# Ответ: утверждение верно
#
# Отрицание: ∃y∈[0;π) ∀ε>0 ∶ cos(y)<cos⁡(y+ε) отрицание ложно

# %% [markdown]
# 6) Утверждение: ∃x ∶ x∋{N,Z,Q,R,C}
#
# Ответ: утверждение верно
#
# Отрицание: ∀x ∶ x∈{N,Z,Q,R,C} отрицание ложно

# %% [markdown]
# #### Найти 12-й член заданной неявно последовательности:
# a1=128, a_(n+1)- a_n=6
#
# an = 128 + 6(n-1)
#
# Ответ:
# a12 = 194
